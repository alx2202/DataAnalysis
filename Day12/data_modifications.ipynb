# %%
import pandas as pd

# %%
url = 'https://github.com/alx2202/DataAnalysis/raw/main/Day11/McDonalds.csv'
df = pd.read_csv(url)
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  TotalFat  \
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df.size
# Out:
# 6240

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# TotalFat                         float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat    TotalFat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %% [markdown]
# ## How we can change column names?
#
# What kind of problems we have with this data set, with those columns?
# - we have spaces in the names and it will cause access to those columns a bit more complicated as I will have to use only ['column name'] approach

# %%
# df.columns[0] = 'Cat'  # KO: TypeError: Index does not support mutable operations

# %% [markdown]
# Although we can't change a particular column we can change all the column names at once by assigning new list with names.

# %%
new_column_names = []
for column in df.columns:
    new_column_names.append(column.lower())
    
df.columns = new_column_names
df
# Out:
#                category                                               item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         serving_size  calories  calories_from_fat  totalfat  \
# ...

# %% [markdown]
# I'd like to do several changes to each column name:
# - replace spaces with `_`
# - replace `%` with `Percentage`
# - replace `(` and `)` with an empty string `''` - basically removing `(` and `)`
#
#
# When we are modifying a string we are getting a new string with changed characters (as desired). We can use method-chaining to perform several changes in one expression.

# %%
df = pd.read_csv(url)

new_column_names = []
for column in df.columns:
    new_column_names.append(column.replace(' ', '_').replace('%', 'Percent').replace('(', '').replace(')', ''))

df.columns = new_column_names
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %%
df = pd.read_csv(url)
df.columns = [column.replace(' ', '_').replace('%', 'Percent').replace('(', '').replace(')', '') for column in df.columns]
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# [`.rename()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html) - we can use `rename` to change column name or names - we can do that for one or several columns.
#
# A lot of functions that we have in Pandas have `inplace` argument, which is set to `False` and this means that the original DatFrame we are working on will not be changed and we will get a copy with changed data. If we use `inplace=True` then the original DataFrame will be changed.

# %%
df.rename(columns={'Category': 'Item_category'})
# Out:
#           Item_category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %%
df.rename(columns={'Category': 'Item_category', 'Item': 'Product'})
# Out:
#           Item_category                                            Product  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# # Data modifications
#
# We have several dedicated methods to change the data within DataFrame or Series objects.
# - [`.replace()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html) - we can think of this methods as a standard find/replace as from Word. If needed we can use regular expressions.
# - [`.fillna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html) - is used to fill/replace [missing values](https://pandas.pydata.org/docs/user_guide/missing_data.html)
# - [`.apply()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html) - allows us to applu any function (either buildin python function, pandas or our own: lambda or standard one defined by `def` keyword).

# %% [markdown]
# ## `replace` - find and replace
#
# This function can be applied to both whole DataFrame (all columns) or particular Series (particular column). Thats an another method that has `inplace` argument.

# %%
df.replace('Breakfast', 'Petit-dejeuner').head(15)
# Out:
#           Category                                               Item  \
# 0   Petit-dejeuner                                       Egg McMuffin
# 1   Petit-dejeuner                                  Egg White Delight
# 2   Petit-dejeuner                                   Sausage McMuffin
# 3   Petit-dejeuner                          Sausage McMuffin with Egg
# 4   Petit-dejeuner                   Sausage McMuffin with Egg Whites
# 5   Petit-dejeuner                               Steak & Egg McMuffin
# 6   Petit-dejeuner      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7   Petit-dejeuner        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8   Petit-dejeuner  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9   Petit-dejeuner  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10  Petit-dejeuner                  Sausage Biscuit (Regular Biscuit)
# 11  Petit-dejeuner                    Sausage Biscuit (Large Biscuit)
# ...

# %%
df.replace(23, -99)
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %%
df.Saturated_Fat.replace(3.0, -100, inplace=True)
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %%
df.Category.unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %% [markdown]
# [`.sample()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html) - returns a random sample of rows from a DataFrame

# %%
df.replace(['Desserts', 'Smoothies & Shakes'], 'Sweets').sample(15)
# Out:
#            Category                                               Item  \
# 174    Coffee & Tea                Nonfat French Vanilla Latte (Large)
# 190    Coffee & Tea                              Hot Chocolate (Small)
# 209    Coffee & Tea  Iced Coffee with Sugar Free French Vanilla Syr...
# 70   Chicken & Fish    Premium McWrap Chicken & Bacon (Crispy Chicken)
# 171    Coffee & Tea                      Nonfat Hazelnut Latte (Large)
# 169    Coffee & Tea                      Nonfat Hazelnut Latte (Small)
# 44      Beef & Pork                Quarter Pounder with Bacon & Cheese
# 145    Coffee & Tea                                     Coffee (Small)
# 211    Coffee & Tea                                 Iced Mocha (Small)
# 114       Beverages                                  Diet Coke (Small)
# 250          Sweets                            Shamrock Shake (Medium)
# 26        Breakfast                          Steak, Egg & Cheese Bagel
# ...

# %% [markdown]
# If I'm providing two lists, then I'm using a mapping between the value I'm looking for and value I'm replacing this value with.

# %%
df.replace(['Breakfast', 'Beverages'], ['Petit-dejeuner', 'Beuverages']).sample(15)
# Out:
#                Category                                               Item  \
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 148        Coffee & Tea                                      Latte (Small)
# 56          Beef & Pork                                              McRib
# 113          Beuverages                          Coca-Cola Classic (Child)
# 11       Petit-dejeuner                    Sausage Biscuit (Large Biscuit)
# 162        Coffee & Tea  Latte with Sugar Free French Vanilla Syrup (La...
# 146        Coffee & Tea                                    Coffee (Medium)
# 161        Coffee & Tea  Latte with Sugar Free French Vanilla Syrup (Me...
# 207        Coffee & Tea                 French Vanilla Iced Coffee (Large)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 183        Coffee & Tea                     Mocha with Nonfat Milk (Large)
# ...

# %% [markdown]
# Another approach: I can provide a disctionary with columns (as key) and list of values I'm looking for (as values for this key) and replace those with something.

# %%
df.replace({
    'Category': ['Breakfast', 'Beverages'],
    'Item': ['Egg McMuffin']
}, 'ABCD')
# Out:
#                Category                                               Item  \
# 0                  ABCD                                               ABCD
# 1                  ABCD                                  Egg White Delight
# 2                  ABCD                                   Sausage McMuffin
# 3                  ABCD                          Sausage McMuffin with Egg
# 4                  ABCD                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# I can provide two dictionaries (both divided by columns) to indicate what I'm looking for and with what value it should be replaced, for a particular column.

# %%
df.replace({
    'Category': ['Breakfast', 'Beverages'],
    'Item': ['Egg McMuffin']
}, {
    'Category': 'AAA',
    'Item': 'BBB'
})
# Out:
#                Category                                               Item  \
# 0                   AAA                                                BBB
# 1                   AAA                                  Egg White Delight
# 2                   AAA                                   Sausage McMuffin
# 3                   AAA                          Sausage McMuffin with Egg
# 4                   AAA                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# We can use regular expressions (regex, regexp).

# %%
# ex. McMuffin -> Muffin
# r'' -> raw, just leave as it is, don't substitute any characters inside starting with \
df.replace(r'Mc(\w+)', r'\1', regex=True)
# Out:
#                Category                                             Item  \
# 0             Breakfast                                       Egg Muffin
# 1             Breakfast                                Egg White Delight
# 2             Breakfast                                   Sausage Muffin
# 3             Breakfast                          Sausage Muffin with Egg
# 4             Breakfast                   Sausage Muffin with Egg Whites
# ..                  ...                                              ...
# 255  Smoothies & Shakes                 Flurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                Flurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 Flurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  Flurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   Flurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# ## `apply`
#
# Applies a function to each value from a DataFrame (row) or Series (value from the column).
#
# ```
# Calories
# 300 -> times_10(300) -> 3000
# 250 -> times_10(250) -> 2500
# 370 -> times_10(370) -> 3700
# ```

# %%
def times_10(number):
    return number * 10

# %%
times_10(50)
# Out:
# 500

# %% [markdown]
# When we are using `apply` with a function defined by `def` keyword we have to provide (as an argument) the name of the function. We can't use `()` after the, because this will execute the function.
#
# Correct: `df.Calories.apply(times_10)`
#
# Incorrect `df.Calories.apply(times_10())`

# %%
df.Calories, df.Calories.apply(times_10)
# Out:
# (0      300
#  1      250
#  2      370
#  3      450
#  4      400
#        ...
#  255    510
#  256    690
#  257    340
#  258    810
#  259    410
#  Name: Calories, Length: 260, dtype: int64,
#  0      3000
#  1      2500
#  2      3700
#  3      4500
#  4      4000
#         ...
#  255    5100
#  256    6900
#  257    3400
#  258    8100
#  259    4100
#  Name: Calories, Length: 260, dtype: int64)

# %% [markdown]
# We can use `lambda` functions as well.

# %%
def times_10(number):
    return number * 10

# %%
df.Calories, df.Calories.apply(lambda number: number * 10)
# Out:
# (0      300
#  1      250
#  2      370
#  3      450
#  4      400
#        ...
#  255    510
#  256    690
#  257    340
#  258    810
#  259    410
#  Name: Calories, Length: 260, dtype: int64,
#  0      3000
#  1      2500
#  2      3700
#  3      4500
#  4      4000
#         ...
#  255    5100
#  256    6900
#  257    3400
#  258    8100
#  259    4100
#  Name: Calories, Length: 260, dtype: int64)

# %%
# it's quite often when changing existing series is to assign the result to new column in the DataFrame
df['CaloriesMultiplied'] = df.Calories.apply(lambda number: number * 10)
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %% [markdown]
# `apply()` is very useful when we want transform existing data into something new. For example we have `Service_Size` column with serving size information but it's stored as a string. That is problematic because I'm not able to to do any intersting mathematical operations on such data. I would like to extract information about grams into a new column, so I can work on it.
#
# Since we are dealing with string that shares the same format, we can leverage regular expressions to get this information.

# %%
import re 

for serving_size in df.Serving_Size:
    matches = re.search(r'\((\d+) g\)', serving_size)
    print(matches.group(1), type(matches.group(1)))
# Out:
# 136 <class 'str'>
# 135 <class 'str'>
# 111 <class 'str'>
# 161 <class 'str'>
# 161 <class 'str'>
# 185 <class 'str'>
# 150 <class 'str'>
# 164 <class 'str'>
# 153 <class 'str'>
# 167 <class 'str'>
# 117 <class 'str'>
# 131 <class 'str'>
# 163 <class 'str'>
# 177 <class 'str'>
# 167 <class 'str'>
# 181 <class 'str'>
# 143 <class 'str'>
# 157 <class 'str'>
# 201 <class 'str'>
# 174 <class 'str'>
# 178 <class 'str'>
# 141 <class 'str'>
# 201 <class 'str'>
# 205 <class 'str'>
# 197 <class 'str'>
# 201 <class 'str'>
# 241 <class 'str'>
# 269 <class 'str'>
# 283 <class 'str'>
# 272 <class 'str'>
# 286 <class 'str'>
# 420 <class 'str'>
# 434 <class 'str'>
# 423 <class 'str'>
# 437 <class 'str'>
# 151 <class 'str'>
# 192 <class 'str'>
# 111 <class 'str'>
# 56 <class 'str'>
# 114 <class 'str'>
# 251 <class 'str'>
# 251 <class 'str'>
# 211 <class 'str'>
# 202 <class 'str'>
# 227 <class 'str'>
# 235 <class 'str'>
# 244 <class 'str'>
# 283 <class 'str'>
# 98 <class 'str'>
# 113 <class 'str'>
# ...

# %%
import numpy as np

def extract_grams(serving_size: str) -> float:
    matches = re.search(r'\((\d+) g\)', serving_size)
    if matches:
        return float(matches.group(1))
    else:
        return np.NaN
    
df['Serving_Size_Grams'] = df.Serving_Size.apply(extract_grams)
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving_Size  Calories  Calories_from_Fat  TotalFat  \
# ...

# %%
df[df['Serving_Size_Grams'].isnull()]
# Out:
#                Category                        Item  Serving_Size  Calories  \
# 110           Beverages   Coca-Cola Classic (Small)  16 fl oz cup       140
# 111           Beverages  Coca-Cola Classic (Medium)  21 fl oz cup       200
# 112           Beverages   Coca-Cola Classic (Large)  30 fl oz cup       280
# 113           Beverages   Coca-Cola Classic (Child)  12 fl oz cup       100
# 114           Beverages           Diet Coke (Small)  16 fl oz cup         0
# ..                  ...                         ...           ...       ...
# 247  Smoothies & Shakes     Chocolate Shake (Small)  12 fl oz cup       560
# 248  Smoothies & Shakes    Chocolate Shake (Medium)  16 fl oz cup       700
# 249  Smoothies & Shakes     Chocolate Shake (Large)  22 fl oz cup       850
# 250  Smoothies & Shakes     Shamrock Shake (Medium)  16 fl oz cup       660
# 251  Smoothies & Shakes      Shamrock Shake (Large)  22 fl oz cup       820
#
# ...
