# %% [markdown]
# # Handling `NaN`s
#
# What is `NaN`? See [Pandas docs](https://pandas.pydata.org/docs/user_guide/missing_data.html)

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://github.com/alx2202/DataAnalysis/raw/main/Day13/employees_ext.csv'
emps = pd.read_csv(url, delimiter=',', parse_dates=['hire_date'], index_col='employee_id')
emps
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.iloc[0], emps.loc[100]
# Out:
# (first_name                     Steven
#  last_name                        King
#  email                           SKING
#  phone_number             515.123.4567
#  hire_date         1987-06-17 00:00:00
#  job_id                        AD_PRES
#  salary                        24000.0
#  commission_pct                    NaN
#  manager_id                        NaN
#  department_id                    90.0
#  Name: 100, dtype: object,
#  first_name                     Steven
#  last_name                        King
#  email                           SKING
#  phone_number             515.123.4567
#  hire_date         1987-06-17 00:00:00
#  job_id                        AD_PRES
#  salary                        24000.0
#  commission_pct                    NaN
#  manager_id                        NaN
#  department_id                    90.0
#  Name: 100, dtype: object)

# %%
emps.sample(15)
# Out:
#               first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 147              Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 175               Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 193              Britney    Everett  BEVERETT        650.501.2876 1997-03-03
# 107                Diana    Lorentz  DLORENTZ        590.423.5567 1999-02-07
# 162                Clara    Vishney  CVISHNEY  011.44.1346.129268 1997-11-11
# 121                 Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 116               Shelli      Baida    SBAIDA        515.127.4563 1997-12-24
# 112          Jose Manuel      Urman   JMURMAN        515.124.4469 1998-03-07
# 104                Bruce      Ernst    BERNST        590.423.4568 1991-05-21
# 168                 Lisa       Ozer     LOZER  011.44.1343.929268 1997-03-11
# 160               Louise      Doran    LDORAN  011.44.1345.629268 1997-12-15
# ...

# %%
emps.isnull()
# Out:
#              first_name  last_name  email  phone_number  hire_date  job_id  \
# employee_id
# 100               False      False  False         False      False   False
# 101               False      False  False         False      False   False
# 102               False      False  False         False      False   False
# 103               False      False  False         False      False   False
# 104               False      False  False         False      False   False
# ...                 ...        ...    ...           ...        ...     ...
# 202               False      False  False         False      False   False
# 203               False      False  False         False      False   False
# 204               False      False  False         False      False   False
# 205               False      False  False         False      False   False
# 206               False      False  False         False      False   False
#
# ...

# %%
# Quick method to see if we have any missing values in our dataframe divided into columns.
# emps.isnull().any()
emps.isnull().any(axis=0)
# Out:
# first_name        False
# last_name         False
# email             False
# phone_number      False
# hire_date         False
# job_id            False
# salary            False
# commission_pct     True
# manager_id         True
# department_id      True
# dtype: bool

# %%
emps.isnull().any(axis=1).sample(20)
# Out:
# employee_id
# 160    False
# 146    False
# 131     True
# 126     True
# 200     True
# 143     True
# 188     True
# 142     True
# 153    False
# 116     True
# 148    False
# 137     True
# 178     True
# 106     True
# 195     True
# 140     True
# 181     True
# 112     True
# 175    False
# 108     True
# dtype: bool

# %% [markdown]
# ## Axes in Pandas
#
# [Axes visually explained](https://stackoverflow.com/a/25774395/779084)
#
# - axis = 0 (this is one is used by default) merges the rows and gives the results oriented into columns
# - axis = 1 merges columns and gives the results oriented into rows

# %%
# get all the rows that contain at least one missing value
# emps.isnull().any(axis=1)
emps[emps.isnull().any(axis=1)]
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# get all the rows that don't have any missing value
emps[~emps.isnull().any(axis=1)]
# Out:
#               first_name   last_name     email        phone_number  hire_date  \
# employee_id
# 145                 John     Russell   JRUSSEL  011.44.1344.429268 1996-10-01
# 146                Karen    Partners  KPARTNER  011.44.1344.467268 1997-01-05
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 148               Gerald   Cambrault  GCAMBRAU  011.44.1344.619268 1999-10-15
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018 2000-01-29
# 150                Peter      Tucker   PTUCKER  011.44.1344.129268 1997-01-30
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268 1997-03-24
# 152                Peter        Hall     PHALL  011.44.1344.478968 1997-08-20
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718 1998-03-30
# 154              Nanette   Cambrault  NCAMBRAU  011.44.1344.987668 1998-12-09
# 155               Oliver     Tuvault  OTUVAULT  011.44.1344.486508 1999-11-23
# ...

# %% [markdown]
# ## How we can replace NaN values with different ones?
#
# ### `.replace()`

# %%
# I'm replacing NaN throughout DataFrame, all the columns and rows are impacted
# by default the original DataFrame is not impacted (you get a copy) unless you pass `inplace=True`.
emps.replace(np.NaN, 0.0)
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %% [markdown]
# ### `.fillna()`
#
# [`.fillna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html?highlight=fillna#pandas.DataFrame.fillna) - replaces missing values (like `NaN`, `NaT`) by given value.

# %%
emps.fillna(0.0)
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.fillna({
    'manager_id': 0.0,
    'commission_pct': 0.99,
})
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.sort_values(['first_name', 'last_name'], inplace=True)
emps.head(10)
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL        650.509.2876 1997-02-20
# 158              Allan     McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175             Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167               Amit      Banda    ABANDA  011.44.1346.729268 2000-04-21
# 187            Anthony     Cabrio   ACABRIO        650.509.4876 1999-02-07
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# to the field containing NaN we will put previous non-NaN value
emps.fillna(method='ffill').head(10)
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL        650.509.2876 1997-02-20
# 158              Allan     McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175             Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167               Amit      Banda    ABANDA  011.44.1346.729268 2000-04-21
# 187            Anthony     Cabrio   ACABRIO        650.509.4876 1999-02-07
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
emps.head(10)
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL        650.509.2876 1997-02-20
# 158              Allan     McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175             Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167               Amit      Banda    ABANDA  011.44.1346.729268 2000-04-21
# 187            Anthony     Cabrio   ACABRIO        650.509.4876 1999-02-07
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# to the field containing NaN we will put first non-NaN value from later rows
emps.fillna(method='bfill').head(10)
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL        650.509.2876 1997-02-20
# 158              Allan     McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175             Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167               Amit      Banda    ABANDA  011.44.1346.729268 2000-04-21
# 187            Anthony     Cabrio   ACABRIO        650.509.4876 1999-02-07
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# we can limit how many rows with NaN will be impacted by such operation
emps.fillna(method='bfill', limit=1).head(10)
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL        650.509.2876 1997-02-20
# 158              Allan     McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175             Alyssa     Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167               Amit      Banda    ABANDA  011.44.1346.729268 2000-04-21
# 187            Anthony     Cabrio   ACABRIO        650.509.4876 1999-02-07
#
#                job_id   salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %% [markdown]
# ## Why we should check and handle `NaN`s in our data?
#
# - `NaN`s will impact many operations we will be doing and this impact may cause unexcepted results of mathematic functions.

# %%
emps
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# ...                ...        ...       ...                 ...        ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560 1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876 1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181 1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268 1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876 1998-01-24
#
# ...

# %% [markdown]
# `.mean()` - is calulated based on non-empty values, so empty/missing values are not included into the calculation. So the following calculation will take only those values from `commission_pct` column where we don't have `NaN`.

# %%
emps.commission_pct.mean()
# Out:
# 0.22285714285714286

# %%
emps[~emps.commission_pct.isnull()]
# Out:
#               first_name   last_name     email        phone_number  hire_date  \
# employee_id
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 158                Allan      McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175               Alyssa      Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167                 Amit       Banda    ABANDA  011.44.1346.729268 2000-04-21
# 179              Charles     Johnson  CJOHNSON  011.44.1644.429262 2000-01-04
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718 1998-03-30
# 162                Clara     Vishney  CVISHNEY  011.44.1346.129268 1997-11-11
# 163             Danielle      Greene   DGREENE  011.44.1346.229268 1999-03-19
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268 1997-03-24
# 165                David         Lee      DLEE  011.44.1346.529268 2000-02-23
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018 2000-01-29
# ...

# %%
emps[~emps.commission_pct.isnull()].commission_pct.mean()
# Out:
# 0.22285714285714286

# %%
# if I want to calculate an average (mean) that includes all the rows
emps.commission_pct.fillna(0.0).mean()
# Out:
# 0.07289719626168224

# %%
emps.commission_pct.mean(skipna=False)
# Out:
# nan

# %%
# emps.commission_pct.isnull()
emps.commission_pct.isna()
# Out:
# employee_id
# 121     True
# 196     True
# 147    False
# 103     True
# 115     True
#        ...
# 106     True
# 195     True
# 206     True
# 171    False
# 180     True
# Name: commission_pct, Length: 107, dtype: bool

# %%
#emps.commission_pct.notnull()
emps.commission_pct.notna()
# Out:
# employee_id
# 121    False
# 196    False
# 147     True
# 103    False
# 115    False
#        ...
# 106    False
# 195    False
# 206    False
# 171     True
# 180    False
# Name: commission_pct, Length: 107, dtype: bool

# %%
# Employess that don't take commission
emps[emps.commission_pct.isna()]
# Out:
#             first_name  last_name     email  phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP  650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH  650.507.9811 1998-04-24
# 103          Alexander     Hunold   AHUNOLD  590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO  515.127.4562 1995-05-18
# 185             Alexis       Bull     ABULL  650.509.2876 1997-02-20
# ...                ...        ...       ...           ...        ...
# 141             Trenna       Rajs     TRAJS  650.121.8009 1995-10-17
# 106              Valli  Pataballa  VPATABAL  590.423.4560 1998-02-05
# 195              Vance      Jones    VJONES  650.501.4876 1999-03-17
# 206            William      Gietz    WGIETZ  515.123.8181 1994-06-07
# 180            Winston     Taylor   WTAYLOR  650.507.9876 1998-01-24
#
#                  job_id  salary  commission_pct  manager_id  department_id
# employee_id
# ...

# %%
# Employess that take commission
emps[emps.commission_pct.notna()]
# Out:
#               first_name   last_name     email        phone_number  hire_date  \
# employee_id
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 158                Allan      McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175               Alyssa      Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167                 Amit       Banda    ABANDA  011.44.1346.729268 2000-04-21
# 179              Charles     Johnson  CJOHNSON  011.44.1644.429262 2000-01-04
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718 1998-03-30
# 162                Clara     Vishney  CVISHNEY  011.44.1346.129268 1997-11-11
# 163             Danielle      Greene   DGREENE  011.44.1346.229268 1999-03-19
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268 1997-03-24
# 165                David         Lee      DLEE  011.44.1346.529268 2000-02-23
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018 2000-01-29
# ...

# %%
sum(emps.commission_pct.isna()), sum(emps.commission_pct.notna())
# Out:
# (72, 35)

# %% [markdown]
# I'd like to calculate total salary for our exmployees, and that would be `salary + salary*commission_pct`.

# %%
emps.salary + emps.salary * emps.commission_pct
# Out:
# employee_id
# 121        NaN
# 196        NaN
# 147    15600.0
# 103        NaN
# 115        NaN
#         ...
# 106        NaN
# 195        NaN
# 206        NaN
# 171     8510.0
# 180        NaN
# Length: 107, dtype: float64

# %% [markdown]
# #### Quick exercise
#
# Within employess DataFrame create new column `total_salary` with total salary for each employee including situation when employee does not have a commission_pct and the one that he has.

# %%
emps['total_salary'] = emps.salary + emps.salary * emps.commission_pct.fillna(0.0)
emps
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# ...                ...        ...       ...                 ...        ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560 1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876 1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181 1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268 1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876 1998-01-24
#
# ...

# %% [markdown]
# ## Removing rows that contain `NaN`s
#
# If we don't want to replace `NaN` by something else we can always ignore those rows that contain `NaN` for our calculations, we can remove them as well from our DataFrame.
#
# For that useful method we can use is [`.dropna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna).

# %%
emps.dropna()  # removing all rows that contain NaN in any column
# Out:
#               first_name   last_name     email        phone_number  hire_date  \
# employee_id
# 147              Alberto   Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 158                Allan      McEwen   AMCEWEN  011.44.1345.829268 1996-08-01
# 175               Alyssa      Hutton   AHUTTON  011.44.1644.429266 1997-03-19
# 167                 Amit       Banda    ABANDA  011.44.1346.729268 2000-04-21
# 179              Charles     Johnson  CJOHNSON  011.44.1644.429262 2000-01-04
# 153          Christopher       Olsen    COLSEN  011.44.1344.498718 1998-03-30
# 162                Clara     Vishney  CVISHNEY  011.44.1346.129268 1997-11-11
# 163             Danielle      Greene   DGREENE  011.44.1346.229268 1999-03-19
# 151                David   Bernstein  DBERNSTE  011.44.1344.345268 1997-03-24
# 165                David         Lee      DLEE  011.44.1346.529268 2000-02-23
# 149                Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018 2000-01-29
# ...

# %% [markdown]
# `how`
#
# - `any` : If any NA values are present, drop that row or column.
# - `all` : If all values are NA, drop that row or column - this option is really useful when we are cleaning the data

# %%
emps.dropna(how='all')
# Out:
#             first_name  last_name     email        phone_number  hire_date  \
# employee_id
# 121               Adam      Fripp    AFRIPP        650.123.2234 1997-04-10
# 196              Alana      Walsh    AWALSH        650.507.9811 1998-04-24
# 147            Alberto  Errazuriz  AERRAZUR  011.44.1344.429278 1997-03-10
# 103          Alexander     Hunold   AHUNOLD        590.423.4567 1990-01-03
# 115          Alexander       Khoo     AKHOO        515.127.4562 1995-05-18
# ...                ...        ...       ...                 ...        ...
# 106              Valli  Pataballa  VPATABAL        590.423.4560 1998-02-05
# 195              Vance      Jones    VJONES        650.501.4876 1999-03-17
# 206            William      Gietz    WGIETZ        515.123.8181 1994-06-07
# 171            William      Smith    WSMITH  011.44.1343.629268 1999-02-23
# 180            Winston     Taylor   WTAYLOR        650.507.9876 1998-01-24
#
# ...

# %% [markdown]
# We can use `subset` argument to provide an information which columns should be checked for `NaN` and if they are found in this subset, then the row will be dropped.

# %%
emps.sort_index(inplace=True)
emps
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 100             Steven      King     SKING  515.123.4567 1987-06-17
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id  \
# employee_id
# ...

# %%
emps.dropna(subset=['manager_id'])
# Out:
#             first_name last_name     email  phone_number  hire_date  \
# employee_id
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568 1989-09-21
# 102                Lex   De Haan   LDEHAAN  515.123.4569 1993-01-13
# 103          Alexander    Hunold   AHUNOLD  590.423.4567 1990-01-03
# 104              Bruce     Ernst    BERNST  590.423.4568 1991-05-21
# 105              David    Austin   DAUSTIN  590.423.4569 1997-06-25
# ...                ...       ...       ...           ...        ...
# 202                Pat       Fay      PFAY  603.123.6666 1997-08-17
# 203              Susan    Mavris   SMAVRIS  515.123.7777 1994-06-07
# 204            Hermann      Baer     HBAER  515.123.8888 1994-06-07
# 205            Shelley   Higgins  SHIGGINS  515.123.8080 1994-06-07
# 206            William     Gietz    WGIETZ  515.123.8181 1994-06-07
#
#                  job_id   salary  commission_pct  manager_id  department_id  \
# employee_id
# ...
